# %%
import numpy as np
import matplotlib.pyplot as plt
import random
import seaborn as sns

# %% [markdown]
# sins = [random.randint(-10,10) * np.sin(random.randint(-10,10)*np.arange(1,101,5)) for _ in range(10)]

# %%
x = np.linspace(0,6)

# %%
sins = [random.randint(-10,10) *np.sin((random.random()*10+1e-2)*x) for i in range(25)]

# %%
plt.plot(np.transpose(sins))

# %%
sns.heatmap(np.linalg.pinv(A.T@A)@(A.T@A))

# %%
A.shape
# Out:
# (50, 10)

# %%
phi = np.array([0.]*15+[1.]*20+[0.]*15)

# %%
A = np.array(sins).T

# %%
phi0=0*phi
phi0[:10]=-5
phi0[-10:]=5

plt.plot(phi0)

# %%
def coeff(A_,phi_):
    c = np.linalg.pinv(A_.T@A_) @ A_.T @ phi_
    return A@c,c

# %%
pr0,c = coeff(A,phi0)

# %%
plt.plot(pr0)
plt.plot(phi0)
